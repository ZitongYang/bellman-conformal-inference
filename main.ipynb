# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
import sys
sys.path.append('.')

from utils import *
from experiment import *
from dataloader.vlfc import COMPANIES
from visualize import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Quick start with a single experiment

# %%
params = read_yaml('config/rtfc-aci-AMD.yaml')
exp = ForecastingExperiment(params)
exp.run()
exp.save()
# Out:
# 2024-02-05 20:59:06,018 - INFO - Experiment rtfc-aci-AMD-gamma_0.1-lambda0_0.9 STARTED
# 2024-02-05 20:59:11,814 - INFO - Experiment rtfc-aci-AMD-gamma_0.1-lambda0_0.9 ENDED in 5.795328855514526s

# %%
visualize_single_exp(exp.params, exp.result)

# %% [markdown]
# # Comparsion of three experiments

# %%
exp_aci = ForecastingExperiment(read_yaml('config/rtfc-aci-AMD.yaml'))
exp_aci.run()

exp_bci = ForecastingExperiment(read_yaml('config/rtfc-bci-AMD.yaml'))
exp_bci.run()

exp_fixed = ForecastingExperiment(read_yaml('config/rtfc-fixed-AMD.yaml'))
exp_fixed.run()
# Out:
# 2024-02-05 20:59:14,277 - INFO - Experiment rtfc-aci-AMD-gamma_0.1-lambda0_0.9 STARTED
# 2024-02-05 20:59:20,046 - INFO - Experiment rtfc-aci-AMD-gamma_0.1-lambda0_0.9 ENDED in 5.769803047180176s
# 2024-02-05 20:59:20,075 - INFO - Experiment rtfc-bci-AMD-gamma_0.8-lambda0_5.0 STARTED
# 2024-02-05 20:59:41,051 - INFO - Experiment rtfc-bci-AMD-gamma_0.8-lambda0_5.0 ENDED in 20.975096225738525s
# 2024-02-05 20:59:41,079 - INFO - Experiment rtfc-fixed-AMD-gamma_NA-lambda0_NA STARTED
# 2024-02-05 20:59:49,703 - INFO - Experiment rtfc-fixed-AMD-gamma_NA-lambda0_NA ENDED in 8.624058723449707s

# %%
visualize_three_exp(exp_aci.params, exp_aci.result,
                    exp_bci.params, exp_bci.result,
                    exp_fixed.params, exp_fixed.result)
